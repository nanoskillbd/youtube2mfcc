# %% [markdown]
# # 🎧 YouTube Audio MFCC Visualization in Python
# This notebook downloads a YouTube video, extracts audio, converts it to WAV, extracts MFCC features, and plots them.

# %%
# ✅ Step 1: Install required libraries
# !pip install yt-dlp librosa matplotlib
# Out:
# Collecting yt-dlp
#   Using cached yt_dlp-2025.6.30-py3-none-any.whl.metadata (174 kB)
# Requirement already satisfied: librosa in c:\users\hasanshahriare\anaconda3\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: matplotlib in c:\users\hasanshahriare\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (0.59.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\hasanshahriare\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hasanshahriare\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.12.14)
# Using cached yt_dlp-2025.6.30-py3-none-any.whl (3.3 MB)
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.6.30

# %%
# ✅ Step 2: Download audio from YouTube
import sys
import subprocess

# Replace this with any public YouTube video URL
url = 'https://www.youtube.com/watch?v=Zi_XLOBDo_Y'  # Michael Jackson - Billie Jean

subprocess.run([sys.executable, '-m', 'yt_dlp',
                '-x', '--audio-format', 'wav',
                '-o', '%(title)s.%(ext)s',
                url])
# Out:
# CompletedProcess(args=['C:\\Users\\HasanShahriare\\anaconda3\\python.exe', '-m', 'yt_dlp', '-x', '--audio-format', 'wav', '-o', '%(title)s.%(ext)s', 'https://www.youtube.com/watch?v=Zi_XLOBDo_Y'], returncode=0)

# %%
# ✅ Step 3: Load and process audio
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load the generated WAV file
file_path = 'mj.wav'  # Update if needed
y, sr = librosa.load(file_path)

# Extract MFCC features
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

# %%
# ✅ Step 4: Visualize MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time', sr=sr)
plt.colorbar()
plt.title('MFCCs of YouTube Audio')
plt.tight_layout()
plt.show()
